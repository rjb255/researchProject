# %% [markdown]
# # Simulated Active Learning Methods
# ## Libraries

# %%
#Standard
import asyncio
from os import getcwd, path
#External
import numpy as np
import pandas as pd
import torch.nn.functional as nnf
from torch.nn.functional import linear

#Custom
from modules.custom import split, getPI

# %% [markdown]
# ## Standard Data Retrival

# %%
dataRoute = path.join(getcwd(), 'data', 'chembl', 'Additional_datasets')
dataSets = [pd.read_csv(path.join(dataRoute, 'data_CHEMBL313.csv')),
            pd.read_csv(path.join(dataRoute, 'data_CHEMBL2637.csv')),
            pd.read_csv(path.join(dataRoute, 'data_CHEMBL4124.csv'))]

data = dataSets[1].sample(frac=1, random_state=1)

display(data)
# Out:
#         molecule_id  pXC50  b0001  b0002  b0003  b0004  b0005  b0006  b0007  \
# 393   CHEMBL1537195  5.225      1      1      1      0      1      0      1
# 607   CHEMBL1783489  4.699      1      1      1      0      1      0      1
# 336   CHEMBL1488035  4.440      1      0      1      0      1      0      1
# 555   CHEMBL1761565  7.155      1      0      1      0      1      0      1
# 325   CHEMBL1477311  5.099      1      0      1      0      1      1      1
# ...             ...    ...    ...    ...    ...    ...    ...    ...    ...
# 715    CHEMBL191003  5.886      1      1      1      0      1      0      1
# 905   CHEMBL2334704  5.579      1      0      1      1      1      0      1
# 1096   CHEMBL494272  5.000      1      1      1      0      1      0      1
# 235   CHEMBL1391112  4.450      1      0      1      0      1      0      1
# 1061   CHEMBL437706  6.277      1      0      1      0      1      0      1
#
#       b0008  ...  b1015  b1016  b1017  b1018  b1019  b1020  b1021  b1022  \
# 393       1  ...      0      0      0      1      0      0      0      0
# 607       0  ...      0      0      1      0      0      0      0      0
# 336       0  ...      0      0      0      0      0      0      1      0
# 555       0  ...      0      1      1      0      0      0      1      0
# 325       0  ...      0      0      1      0      0      0      0      0
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 715       0  ...      0      0      1      0      0      0      0      0
# 905       0  ...      0      1      1      0      0      0      1      0
# 1096      0  ...      0      1      1      0      0      0      1      0
# 235       0  ...      0      0      1      0      0      0      0      0
# 1061      0  ...      0      1      1      0      0      0      0      0
#
#       b1023  b1024
# 393       0      0
# 607       0      0
# 336       0      0
# 555       0      0
# 325       0      0
# ...     ...    ...
# 715       0      0
# 905       0      0
# 1096      0      0
# 235       0      0
# 1061      0      0
#
# [1211 rows x 1026 columns]

# %% [markdown]
# ## Single Model, Least Certain

# %%
## Model Selection is not being tested here, so linear regression is used for speed
X_known, Y_known, X_unknown, Y_unknown, X_test, Y_test = split(data)

pipe.fit(X_known, Y_known)
pred_y, std_y = pipe.predict(X_unknown, return_std=True)
std_y.sort_values()
# Out:
# 445     0.001531
# 841     0.001598
# 122     0.001619
# 588     0.001621
# 229     0.001806
#           ...
# 935     0.142569
# 397     0.143925
# 282     0.147873
# 2       0.152804
# 1201    0.161027
# Length: 1069, dtype: float64

# %%
score1 = []
score2 = []
additional = 20

for i in range(additional):
    print(f"\r{i+1} of {additional}", end="")
    x1, y1, _, _, _, _ = split(data, 20 + i)
    pipe.fit(x1, y1)
    score1.append(pipe.score(X_test, Y_test))

for i in range(additional):
    print(f"\r{i+1} of {additional}", end="")
    pipe.fit(X_known, Y_known)
    pred_y, std_y = pipe.predict(X_unknown, return_std=True)
    index = std_y.sort_values()
    score2.append(pipe.score(X_test, Y_test))
    X_known, Y_known, X_unknown, Y_unknown = getPI((X_known, Y_known), (X_unknown, Y_unknown), index.index[-1], data)

plt.plot(score1)
plt.plot(score2)
# Out:
# 20 of 20

# %%
plt.plot(score1)

# %% [markdown]
# ## Different Models

# %%
X_known, Y_known, X_unknown, Y_unknown, X_test, Y_test = split(data)

for pipe in pipes:
    pipe.fit(X_known, Y_known)
    print(pipe.predict_proba(X_unknown))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1147/3596007088.py in <module>
#       8
#       9 for pipe in pipes:
# ---> 10     pipe.fit(X_known, Y_known)
#      11     print(pipe.predict_proba(X_unknown))
#
# ~/.local/lib/python3.9/site-packages/sklearn/pipeline.py in fit(self, X, y, **fit_params)
#     392             if self._final_estimator != "passthrough":
#     393                 fit_params_last_step = fit_params_steps[self.steps[-1][0]]
# --> 394                 self._final_estimator.fit(Xt, y, **fit_params_last_step)
#     395
#     396         return self
#
# ~/.local/lib/python3.9/site-packages/sklearn/naive_bayes.py in fit(self, X, y, sample_weight)
#     665
#     666         labelbin = LabelBinarizer()
# --> 667         Y = labelbin.fit_transform(y)
#     668         self.classes_ = labelbin.classes_
#     669         if Y.shape[1] == 1:
#
# ~/.local/lib/python3.9/site-packages/sklearn/preprocessing/_label.py in fit_transform(self, y)
#     322             will be of CSR format.
#     323         """
# --> 324         return self.fit(y).transform(y)
#     325
#     326     def transform(self, y):
#
# ~/.local/lib/python3.9/site-packages/sklearn/preprocessing/_label.py in fit(self, y)
#     299
#     300         self.sparse_input_ = sp.issparse(y)
# --> 301         self.classes_ = unique_labels(y)
#     302         return self
#     303
#
# ~/.local/lib/python3.9/site-packages/sklearn/utils/multiclass.py in unique_labels(*ys)
#     100     _unique_labels = _FN_UNIQUE_LABELS.get(label_type, None)
#     101     if not _unique_labels:
# --> 102         raise ValueError("Unknown label type: %s" % repr(ys))
#     103
#     104     ys_labels = set(chain.from_iterable(_unique_labels(y) for y in ys))
#
# ValueError: Unknown label type: (array([5.225, 4.699, 4.44 , 7.155, 5.099, 4.306, 5.   , 4.046, 6.333,
#        7.432, 5.229, 6.387, 5.301, 5.5  , 5.25 , 5.5  , 6.444, 4.307,
#        5.   , 5.699]),)

# %%
pipe
# Out:
# Pipeline(steps=[('model', MultinomialNB())])
